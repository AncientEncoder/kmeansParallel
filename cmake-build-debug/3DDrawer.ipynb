# %%
import matplotlib.pyplot as plt
import numpy as np
import tqdm.notebook as tqdm

# %%
cnames = ['red', 'orange', 'yellow', 'green', 'cyan', 'blue', 'purple']
path = 'result.txt'

# %%
def dataReader(objectFilePath):
    with open(objectFilePath) as file:
        points = []
        while 1:
            line = file.readline()
            if not line:
                break
            lines = line.split(" ")
            dataLine= [(float(lines[0]) * 100, float(lines[1]) * 100, float(lines[2]) * 100), int(lines[3])]
            # print(lines)
            points.append(dataLine)
    points = np.array(points)
    return points

# %%
data=[]
data = dataReader(path)
print(data)
# Out:
# [[(120.381, 123.98400000000001, -208.90800000000002) 0]
#  [(147.654, 131.864, -220.524) 0]
#  [(172.893, 139.157, -231.28700000000003) 0]
#  ...
#  [(-89.61, 41.24, -16.43) 4]
#  [(-75.7, 48.209999999999994, -44.1) 4]
#  [(-36.38, 35.28, -86.21) 4]]
# c:\Users\Mikhail\.conda\envs\Kmeasn\lib\site-packages\ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   if sys.path[0] == "":

# %%
graphic = plt.subplot(111, projection="3d")
size=data.size
bar=tqdm.tqdm(data)
for i in bar:
    bar.set_description(f"Now get element from center {i[1]}")
    graphic.scatter((i[0][0]), (i[0][1]), (i[0][2]), c=cnames[int(i[1])])
plt.show()
# Out:
#   0%|          | 0/88521 [00:00<?, ?it/s]
